# %% [markdown]
# <a href="https://colab.research.google.com/github/invest41/Exploring_Libraries/blob/main/New_Features_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **New Features on Google Colab**
# Author: [Alao David I.](https://github.com/invest41)
# Date: 7th Nov., 2021

# %% [markdown]
# #### **Prerequisites**

# %% [markdown]
# ##### **Setting up the Environment**
#
# > *Note: Name of Imported Modules and Functions are used as is, for better description*

# %%
import sys
import random

import numpy, pandas, seaborn
from matplotlib import pyplot

# %% [markdown]
# ##### **Firstly, let's check our Python version**

# %%
pyVer = sys.version
"Python Version is {}".format(pyVer[:pyVer.rfind('(')])
# Out:
# 'Python Version is 3.7.12 '

# %% [markdown]
# #### A) **Variable Inspector**

# %% [markdown]
# ![IMG_9878.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ##### **Try out different Data Types**

# %%
a = 35
b = 3.5
c = 'abc'
d = b'abc'
e = [1,2,3,4]
f = (1,2,3,4)
g = {1,2,3,4}
h = {1:2, 3:4, 5:6}
i = True
j = None

# %% [markdown]
# ##### **Sophisticated Functions, Modules and Libraries**

# %%
froz = frozenset({1, 2, 3, 4})
froz
# Out:
# frozenset({1, 2, 3, 4})

# %%
bytA = bytearray(7)
bytA
# Out:
# bytearray(b'\x00\x00\x00\x00\x00\x00\x00')

# %%
memView = memoryview(bytes(7))
memView

# %%
run = range(5)
run
# Out:
# range(0, 5)

# %%
m = map(lambda x: x*2, [1,2])
print(m, list(m), sep='\n')
# Out:
# ...
# [2, 4]

# %%
num = numpy.ones((3,2))
num
# Out:
# array([[1., 1.],
#        [1., 1.],
#        [1., 1.]])

# %%
s = pandas.Series(num.flatten(), name = 'array')
print(type(s), s, sep='\n')
# Out:
# <class 'pandas.core.series.Series'>
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# 5    1.0
# Name: array, dtype: float64

# %%
df = s.to_frame()
print(type(df), df, sep='\n')
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    array
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# 5    1.0

# %%
fig = pyplot.figure(figsize=(16,6))

# %%
ax = df.plot
axis = ax(kind = 'line')


#I do not want the plot to show yet
# %matplotlib inline

# %%
fw = open('test.txt', 'w')
fw
# Out:
# <_io.TextIOWrapper name='test.txt' mode='w' encoding='UTF-8'>

# %% [markdown]
# ##### **Exceptions**

# %% [markdown]
# ###### 1) **Doesn't work on assigned modules, objects, methods, and functions**

# %%
siri = pandas.Series
siri
# Out:
# pandas.core.series.Series

# %%
ran = random.random
type(ran)
# Out:
# builtin_function_or_method

# %%
def myFunc(): pass

func = myFunc
func
# Out:
# <function __main__.myFunc>

# %%
exp = BaseException
exp
# Out:
# BaseException

# %% [markdown]
# ###### 2) **Note:**
#
# *   *Reassigning a variable multiple times, in a short period, might cause it not to appear in the variable inspector panel.*
#
#
# * Deleting a variable removes it from the variable inspector panel.
# ```python
# >>> del variable
# ```

# %% [markdown]
# ##### **Result**
# ![A9B2269A-A58E-426E-A11D-7768568F0B6C.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# #### B) **Markdown additions**

# %% [markdown]
# ![IMG_9877.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# 1.  **Trident Symbol**
#  *   Used to Add Symbols to your Markdown
#  *   Examples:
#      * ᵅ -> \^alpha
#      * ᵟ -> \^delta
#      * 𝜆 -> \mitlambda
# 2. **Emoji Symbol**
#  *   Used to add popular emojis to your Markdown
#  *   Examples:
#      *   ✅ -> :check-mark
#      *   ☢ -> :radioactive
#      *   😏 -> :smirk

# %% [markdown]
# ### **Let's Connect**
# | | | |
# |:--|:--|:--|
# |[Project Portfolio](https://invest41.github.io/AlaoDavid.github.io/)|[GitHub](https://github.com/invest41)|[Twitter](https://mobile.twitter.com/Wilder_Maxim)|
# |[Kaggle](https://www.kaggle.com/welcomehere)| [Linkedin](https://www.linkedin.com/in/david-alao-72362113b/)|[Tableau](https://public.tableau.com/app/profile/alao.david)|
